# %%
# SPECIFICATIONS
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.datasets import boston_housing
from keras.optimizers import Adam
from sklearn.preprocessing import StandardScaler

# %%
# LOAD DATASET
(x_train, y_train), (x_test, y_test) = boston_housing.load_data()

scalar = StandardScaler()
x_train = scalar.fit_transform(x_train)
x_test = scalar.transform(x_test)

# %%
# BUILD AND TRAIN MODEL
model = Sequential()
model.add(Dense(15, activation='relu', input_shape=(x_train.shape[1],)))
model.add(Dense(15, activation='relu'))
model.add(Dense(15, activation='relu'))
model.add(Dense(1, activation='relu'))

model.summary()
model.compile(optimizer=Adam(learning_rate=0.01), loss='mean_absolute_error')
history = model.fit(x_train, y_train, epochs=20, batch_size=10, validation_split=0.15)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 15)                210
#
#  dense_1 (Dense)             (None, 15)                240
#
#  dense_2 (Dense)             (None, 15)                240
#
#  dense_3 (Dense)             (None, 1)                 16
#
# =================================================================
# Total params: 706
# Trainable params: 706
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 35/35 [==============================] - 1s 10ms/step - loss: 14.5120 - val_loss: 6.4200
# Epoch 2/20
# 35/35 [==============================] - 0s 2ms/step - loss: 4.4563 - val_loss: 3.8893
# Epoch 3/20
# 35/35 [==============================] - 0s 2ms/step - loss: 3.5842 - val_loss: 3.3274
# Epoch 4/20
# 35/35 [==============================] - 0s 2ms/step - loss: 2.8786 - val_loss: 2.8088
# Epoch 5/20
# 35/35 [==============================] - 0s 2ms/step - loss: 2.8957 - val_loss: 2.5598
# Epoch 6/20
# 35/35 [==============================] - 0s 2ms/step - loss: 2.4642 - val_loss: 2.4505
# Epoch 7/20
# 35/35 [==============================] - 0s 2ms/step - loss: 2.4283 - val_loss: 2.8769
# Epoch 8/20
# 35/35 [==============================] - 0s 2ms/step - loss: 2.4324 - val_loss: 2.5983
# Epoch 9/20
# 35/35 [==============================] - 0s 2ms/step - loss: 2.3465 - val_loss: 2.2672
# Epoch 10/20
# 35/35 [==============================] - 0s 2ms/step - loss: 2.3935 - val_loss: 2.3999
# Epoch 11/20
# 35/35 [==============================] - 0s 2ms/step - loss: 2.2509 - val_loss: 2.3888
# Epoch 12/20
# 35/35 [==============================] - 0s 3ms/step - loss: 2.1692 - val_loss: 2.4156
# Epoch 13/20
# 35/35 [==============================] - 0s 2ms/step - loss: 2.4695 - val_loss: 2.6674
# Epoch 14/20
# 35/35 [==============================] - 0s 2ms/step - loss: 2.1800 - val_loss: 2.2360
# Epoch 15/20
# 35/35 [==============================] - 0s 4ms/step - loss: 2.2414 - val_loss: 2.9043
# Epoch 16/20
# 35/35 [==============================] - 0s 2ms/step - loss: 2.3583 - val_loss: 2.3426
# Epoch 17/20
# 35/35 [==============================] - 0s 2ms/step - loss: 2.0754 - val_loss: 2.4018
# Epoch 18/20
# 35/35 [==============================] - 0s 3ms/step - loss: 2.0740 - val_loss: 2.4210
# Epoch 19/20
# 35/35 [==============================] - 0s 2ms/step - loss: 2.1266 - val_loss: 2.2834
# Epoch 20/20
# 35/35 [==============================] - 0s 2ms/step - loss: 2.1253 - val_loss: 2.3736

# %%
# PREDICT
test_loss = model.evaluate(x_test, y_test)
print("Test Loss:", test_loss)

# Generate the actual predictions for our test set
predictions = model.predict(x_test)
# Out:
# 4/4 [==============================] - 0s 1ms/step - loss: 2.7231
# Test Loss: 2.7231385707855225
# 4/4 [==============================] - 0s 2ms/step

# %%
# TRAINING AND VALIDATION PLOT
import matplotlib.pyplot as plt

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
# ReLU ACTIVATION FUNCTION
import matplotlib.pyplot as plt

input_values = np.linspace(-3, 3, 100)
output_values = np.maximum(input_values, 0)

plt.plot(input_values, output_values)
plt.title('ReLU Activation Function')
plt.xlabel('Input')
plt.ylabel('Output')
plt.grid(True)
plt.show()
