# %%
# SPECIFICATIONS
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation, BatchNormalization
from keras.datasets import boston_housing
from keras.optimizers import Adam
from sklearn.preprocessing import StandardScaler

# %%
# LOAD DATASET
(x_train, y_train), (x_test, y_test) = boston_housing.load_data()

scalar = StandardScaler()
x_train = scalar.fit_transform(x_train)
x_test = scalar.transform(x_test)

# %%
# BUILD AND TRAIN MODEL
model = Sequential()
model.add(Dense(15, activation='relu', input_shape=(x_train.shape[1],)))
model.add(BatchNormalization())  # Adding Batch Normalization layer
model.add(Dense(15, activation='relu'))
model.add(BatchNormalization())  # Adding Batch Normalization layer
model.add(Dense(15, activation='relu'))
model.add(BatchNormalization())  # Adding Batch Normalization layer
model.add(Dense(1, activation='relu'))

model.summary()
model.compile(optimizer=Adam(learning_rate=0.01), loss='mean_absolute_error')
history = model.fit(x_train, y_train, epochs=20, batch_size=10, validation_split=0.15)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 15)                210
#
#  batch_normalization (BatchN  (None, 15)               60
#  ormalization)
#
#  dense_1 (Dense)             (None, 15)                240
#
#  batch_normalization_1 (Batc  (None, 15)               60
#  hNormalization)
#
#  dense_2 (Dense)             (None, 15)                240
#
#  batch_normalization_2 (Batc  (None, 15)               60
#  hNormalization)
#
#  dense_3 (Dense)             (None, 1)                 16
#
# =================================================================
# Total params: 886
# Trainable params: 796
# Non-trainable params: 90
# _________________________________________________________________
# Epoch 1/20
# 35/35 [==============================] - 2s 11ms/step - loss: 19.0876 - val_loss: 17.3898
# Epoch 2/20
# 35/35 [==============================] - 0s 3ms/step - loss: 13.0667 - val_loss: 8.7950
# Epoch 3/20
# 35/35 [==============================] - 0s 3ms/step - loss: 7.9782 - val_loss: 10.8629
# Epoch 4/20
# 35/35 [==============================] - 0s 3ms/step - loss: 7.1432 - val_loss: 10.1713
# Epoch 5/20
# 35/35 [==============================] - 0s 3ms/step - loss: 6.6206 - val_loss: 6.9341
# Epoch 6/20
# 35/35 [==============================] - 0s 4ms/step - loss: 5.9480 - val_loss: 6.8428
# Epoch 7/20
# 35/35 [==============================] - 0s 3ms/step - loss: 5.5903 - val_loss: 4.9447
# Epoch 8/20
# 35/35 [==============================] - 0s 4ms/step - loss: 5.1836 - val_loss: 4.3031
# Epoch 9/20
# 35/35 [==============================] - 0s 6ms/step - loss: 3.8919 - val_loss: 5.9878
# Epoch 10/20
# 35/35 [==============================] - 0s 4ms/step - loss: 3.7227 - val_loss: 5.8648
# Epoch 11/20
# 35/35 [==============================] - 0s 3ms/step - loss: 3.6032 - val_loss: 4.7398
# Epoch 12/20
# 35/35 [==============================] - 0s 3ms/step - loss: 3.8687 - val_loss: 3.6750
# Epoch 13/20
# 35/35 [==============================] - 0s 3ms/step - loss: 3.6256 - val_loss: 3.6490
# Epoch 14/20
# 35/35 [==============================] - 0s 3ms/step - loss: 3.4741 - val_loss: 3.8217
# Epoch 15/20
# 35/35 [==============================] - 0s 3ms/step - loss: 3.7448 - val_loss: 2.8020
# Epoch 16/20
# 35/35 [==============================] - 0s 3ms/step - loss: 3.7445 - val_loss: 3.2929
# Epoch 17/20
# 35/35 [==============================] - 0s 4ms/step - loss: 3.7893 - val_loss: 3.0580
# Epoch 18/20
# 35/35 [==============================] - 0s 4ms/step - loss: 3.9828 - val_loss: 2.8400
# Epoch 19/20
# 35/35 [==============================] - 0s 3ms/step - loss: 3.4292 - val_loss: 2.8937
# Epoch 20/20
# 35/35 [==============================] - 0s 2ms/step - loss: 3.7943 - val_loss: 3.7959

# %%
# PREDICT
test_loss = model.evaluate(x_test, y_test)
print("Test Loss:", test_loss)

predictions = model.predict(x_test)
# Out:
# 4/4 [==============================] - 0s 0s/step - loss: 4.1123
# Test Loss: 4.11230993270874
# 4/4 [==============================] - 0s 0s/step

# %%
# TRAINING AND VALIDATION PLOT
import matplotlib.pyplot as plt

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
